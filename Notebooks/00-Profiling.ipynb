# %%
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import os
import pandas_profiling
import plotly.plotly as py
import plotly.graph_objs as go
import cufflinks as cf
import plotly.offline
# %matplotlib inline
sns.set(color_codes=True)

cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
arquivos = os.listdir("../Alfred/")
arquivos
# Out:
# ['genre.csv',
#  'movie.csv',
#  'theater_tag.csv',
#  'tag.csv',
#  'user.csv',
#  'interaction_mood.csv',
#  'room.csv',
#  'theater.csv',
#  'notification.csv',
#  'movie_trailer.csv',
#  'promotion_theater.csv',
#  'user_genre.csv',
#  'mood.csv',
#  'movie_room_schedule.csv',
#  'schedule.csv',
#  'grid.csv',
#  'device_token.csv',
#  'user_theater.csv',
#  'user_friend.csv',
#  'city.csv',
#  'sync_log.csv',
#  'user_mood.csv',
#  'room_tag.csv',
#  'checkin.csv',
#  'texts.csv',
#  'promotion.csv',
#  'interaction.csv',
#  'movie_mood.csv']

# %%
genre = pd.read_csv("../Alfred/"+arquivos[0])
movie = pd.read_csv("../Alfred/"+arquivos[1])
theater_tag = pd.read_csv("../Alfred/"+arquivos[2])
tag = pd.read_csv("../Alfred/"+arquivos[3])
user = pd.read_csv("../Alfred/"+arquivos[4])
interaction_mood = pd.read_csv("../Alfred/"+arquivos[5])
room = pd.read_csv("../Alfred/"+arquivos[6])
theater = pd.read_csv("../Alfred/"+arquivos[7])
notification = pd.read_csv("../Alfred/"+arquivos[8])
movie_trailer = pd.read_csv("../Alfred/"+arquivos[9])
promotion_theater = pd.read_csv("../Alfred/"+arquivos[10])
user_genre = pd.read_csv("../Alfred/"+arquivos[11])
mood = pd.read_csv("../Alfred/"+arquivos[12])
movie_room_schedule = pd.read_csv("../Alfred/"+arquivos[13])
schedule = pd.read_csv("../Alfred/"+arquivos[14])
grid = pd.read_csv("../Alfred/"+arquivos[15])
device_token = pd.read_csv("../Alfred/"+arquivos[16])
user_theater = pd.read_csv("../Alfred/"+arquivos[17])
user_friend = pd.read_csv("../Alfred/"+arquivos[18])
city = pd.read_csv("../Alfred/"+arquivos[19])
sync_log = pd.read_csv("../Alfred/"+arquivos[20])
user_mood = pd.read_csv("../Alfred/"+arquivos[21])
room_tag = pd.read_csv("../Alfred/"+arquivos[22])
checkin = pd.read_csv("../Alfred/"+arquivos[23])
texts = pd.read_csv("../Alfred/"+arquivos[24])
promotion = pd.read_csv("../Alfred/"+arquivos[25])
interaction = pd.read_csv("../Alfred/"+arquivos[26])
movie_mood = pd.read_csv("../Alfred/"+arquivos[27])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning:
#
# Columns (3,19) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning:
#
# Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
profile_genre = pandas_profiling.ProfileReport(genre)
profile_genre.to_file(outputfile="genre-data-profiling.html")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
profile_theater_tag = pandas_profiling.ProfileReport(theater_tag)
profile_theater_tag.to_file(outputfile="theater_tag-data-profiling.html")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
profile_tag = pandas_profiling.ProfileReport(tag)
profile_tag.to_file(outputfile="tag-data-profiling.html")

# %%
profile_interaction_mood = pandas_profiling.ProfileReport(interaction_mood)
profile_interaction_mood.to_file(outputfile="interaction_mood-data-profiling.html")

# %%
profile_room = pandas_profiling.ProfileReport(room)
profile_room.to_file(outputfile="room-data-profiling.html")

# %%
profile_theater = pandas_profiling.ProfileReport(theater)
profile_theater.to_file(outputfile="theater-data-profiling.html")

# %%
profile_notification = pandas_profiling.ProfileReport(notification)
profile_notification.to_file(outputfile="notification-data-profiling.html")

# %%
profile_movie_trailer = pandas_profiling.ProfileReport(movie_trailer)
profile_movie_trailer.to_file(outputfile="movie_trailer-data-profiling.html")

# %%
profile_promotion_theater = pandas_profiling.ProfileReport(promotion_theater)
profile_promotion_theater.to_file(outputfile="promotion_theater-data-profiling.html")

# %%
profile_user_genre = pandas_profiling.ProfileReport(user_genre)
profile_user_genre.to_file(outputfile="user_genre-data-profiling.html")

# %%
profile_mood = pandas_profiling.ProfileReport(mood)
profile_mood.to_file(outputfile="mood-data-profiling.html")

# %%
profile_movie_room_schedule = pandas_profiling.ProfileReport(movie_room_schedule)
profile_movie_room_schedule.to_file(outputfile="movie_room_schedule-data-profiling.html")

# %%
profile_schedule = pandas_profiling.ProfileReport(schedule)
profile_schedule.to_file(outputfile="schedule-data-profiling.html")

# %%
profile_grid = pandas_profiling.ProfileReport(grid)
profile_grid.to_file(outputfile="grid-data-profiling.html")

# %%
profile_device_token = pandas_profiling.ProfileReport(device_token)
profile_device_token.to_file(outputfile="device_token-data-profiling.html")

# %%
profile_user_theater = pandas_profiling.ProfileReport(user_theater)
profile_user_theater.to_file(outputfile="user_theater-data-profiling.html")

# %%
profile_user_friend = pandas_profiling.ProfileReport(user_friend)
profile_user_friend.to_file(outputfile="user_friend-data-profiling.html")

# %%
profile_city = pandas_profiling.ProfileReport(city)
profile_city.to_file(outputfile="city-data-profiling.html")

# %%
profile_sync_log = pandas_profiling.ProfileReport(sync_log)
profile_sync_log.to_file(outputfile="sync_log-data-profiling.html")

# %%
profile_user_mood = pandas_profiling.ProfileReport(user_mood)
profile_user_mood.to_file(outputfile="user_mood-data-profiling.html")

# %%
profile_room_tag = pandas_profiling.ProfileReport(room_tag)
profile_room_tag.to_file(outputfile="room_tag-data-profiling.html")

# %%
profile_checkin = pandas_profiling.ProfileReport(checkin)
profile_checkin.to_file(outputfile="checkin-data-profiling.html")

# %%
profile_texts = pandas_profiling.ProfileReport(texts)
profile_texts.to_file(outputfile="texts-data-profiling.html")

# %%
profile_promotion = pandas_profiling.ProfileReport(promotion)
profile_promotion.to_file(outputfile="promotion-data-profiling.html")

# %%
profile_interaction = pandas_profiling.ProfileReport(interaction)
profile_interaction.to_file(outputfile="interaction-data-profiling.html")

# %%
profile_movie_mood = pandas_profiling.ProfileReport(movie_mood)
profile_movie_mood.to_file(outputfile="movie_mood-data-profiling.html")

# %%
df = movie.merge(movie_mood, how = 'left', left_on = 'id', right_on = 'movieId', suffixes=["_mv", "_mm"])
df = df.merge(mood, how = 'left', left_on = 'moodId', right_on = 'id', suffixes=["_mm", "_md"])
df = df.merge(genre, how = 'left', left_on = 'id_mv', right_on = 'id', suffixes=["_mv", "_gr"])
df = df.merge(user_genre, how = 'left', left_on = 'id_gr', right_on = 'genreId', suffixes=["_gr", "_ug"])
df = df.merge(user, how = 'left', left_on = 'userId', right_on = 'id', suffixes=["_ug", "_u"])

# %% [markdown]
# ### Tabela Movie

# %%
profile_movie = pandas_profiling.ProfileReport(movie)
profile_movie.to_file(outputfile="movie-data-profiling.html")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
pandas_profiling.ProfileReport(movie)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
# ...

# %% [markdown]
# ### Tabela User

# %%
profile_user = pandas_profiling.ProfileReport(user)
profile_user.to_file(outputfile="user-data-profiling.html")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
pandas_profiling.ProfileReport(user)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
# ...

# %% [markdown]
# ### Tabela Theater

# %%
profile_theater = pandas_profiling.ProfileReport(theater)
profile_theater.to_file(outputfile="theater-data-profiling.html")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
pandas_profiling.ProfileReport(theater)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
# ...

# %% [markdown]
# ### Tabela Genre

# %%
profile_genre = pandas_profiling.ProfileReport(genre)
profile_genre.to_file(outputfile="genre-data-profiling.html")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
pandas_profiling.ProfileReport(genre)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
# ...

# %% [markdown]
# ## Tabela Geral

# %%
df
# Out:
#          id_mv  genreId_gr                       title_mm  \
# 0            1           5  000 - UM AGENTE NADA DISCRETO
# 1            1           5  000 - UM AGENTE NADA DISCRETO
# 2            1           5  000 - UM AGENTE NADA DISCRETO
# 3            1           5  000 - UM AGENTE NADA DISCRETO
# 4            1           5  000 - UM AGENTE NADA DISCRETO
# 5            1           5  000 - UM AGENTE NADA DISCRETO
# 6            1           5  000 - UM AGENTE NADA DISCRETO
# 7            1           5  000 - UM AGENTE NADA DISCRETO
# 8            1           5  000 - UM AGENTE NADA DISCRETO
# 9            1           5  000 - UM AGENTE NADA DISCRETO
# 10           1           5  000 - UM AGENTE NADA DISCRETO
# 11           1           5  000 - UM AGENTE NADA DISCRETO
# 12           1           5  000 - UM AGENTE NADA DISCRETO
# 13           1           5  000 - UM AGENTE NADA DISCRETO
# 14           1           5  000 - UM AGENTE NADA DISCRETO
# ...

# %%
profile = df.profile_report(title='Pandas Profiling Report', plot={'histogram': {'bins': 8}})
profile.to_file(output_file="output.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7735de93c921> in <module>
# ----> 1 profile = df.profile_report(title='Pandas Profiling Report', plot={'histogram': {'bins': 8}})
#       2 profile.to_file(output_file="output.html")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_file(outputfile="alfred-data-profiling.html")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
