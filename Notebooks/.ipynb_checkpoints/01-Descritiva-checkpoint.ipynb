# %%
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import os
import pandas_profiling
import plotly.plotly as py
import plotly.graph_objs as go
import cufflinks as cf
import plotly.offline
# %matplotlib inline
sns.set(color_codes=True)

cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
arquivos = os.listdir("../Alfred/")
arquivos
# Out:
# ['genre.csv',
#  'movie.csv',
#  'theater_tag.csv',
#  'tag.csv',
#  'user.csv',
#  'interaction_mood.csv',
#  'room.csv',
#  'theater.csv',
#  'notification.csv',
#  'movie_trailer.csv',
#  'promotion_theater.csv',
#  'user_genre.csv',
#  'mood.csv',
#  'movie_room_schedule.csv',
#  'schedule.csv',
#  'grid.csv',
#  'device_token.csv',
#  'user_theater.csv',
#  'user_friend.csv',
#  'city.csv',
#  'sync_log.csv',
#  'user_mood.csv',
#  'room_tag.csv',
#  'checkin.csv',
#  'texts.csv',
#  'promotion.csv',
#  'interaction.csv',
#  'movie_mood.csv']

# %%
genre = pd.read_csv("../Alfred/"+arquivos[0])
movie = pd.read_csv("../Alfred/"+arquivos[1])
theater_tag = pd.read_csv("../Alfred/"+arquivos[2])
tag = pd.read_csv("../Alfred/"+arquivos[3])
user = pd.read_csv("../Alfred/"+arquivos[4])
interaction_mood = pd.read_csv("../Alfred/"+arquivos[5])
room = pd.read_csv("../Alfred/"+arquivos[6])
theater = pd.read_csv("../Alfred/"+arquivos[7])
notification = pd.read_csv("../Alfred/"+arquivos[8])
movie_trailer = pd.read_csv("../Alfred/"+arquivos[9])
promotion_theater = pd.read_csv("../Alfred/"+arquivos[10])
user_genre = pd.read_csv("../Alfred/"+arquivos[11])
mood = pd.read_csv("../Alfred/"+arquivos[12])
movie_room_schedule = pd.read_csv("../Alfred/"+arquivos[13])
schedule = pd.read_csv("../Alfred/"+arquivos[14])
grid = pd.read_csv("../Alfred/"+arquivos[15])
device_token = pd.read_csv("../Alfred/"+arquivos[16])
user_theater = pd.read_csv("../Alfred/"+arquivos[17])
user_friend = pd.read_csv("../Alfred/"+arquivos[18])
city = pd.read_csv("../Alfred/"+arquivos[19])
sync_log = pd.read_csv("../Alfred/"+arquivos[20])
user_mood = pd.read_csv("../Alfred/"+arquivos[21])
room_tag = pd.read_csv("../Alfred/"+arquivos[22])
checkin = pd.read_csv("../Alfred/"+arquivos[23])
texts = pd.read_csv("../Alfred/"+arquivos[24])
promotion = pd.read_csv("../Alfred/"+arquivos[25])
interaction = pd.read_csv("../Alfred/"+arquivos[26])
movie_mood = pd.read_csv("../Alfred/"+arquivos[27])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning:
#
# Columns (3,19) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning:
#
# Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df = movie.merge(movie_mood, how = 'left', left_on = 'id', right_on = 'movieId', suffixes=["_mv", "_mm"])
df = df.merge(mood, how = 'left', left_on = 'moodId', right_on = 'id', suffixes=["_mm", "_md"])
df = df.merge(genre, how = 'left', left_on = 'id_mv', right_on = 'id', suffixes=["_mv", "_gr"])
df = df.merge(user_genre, how = 'left', left_on = 'id_gr', right_on = 'genreId', suffixes=["_gr", "_ug"])
df = df.merge(user, how = 'left', left_on = 'userId', right_on = 'id', suffixes=["_ug", "_u"])

# %%
series = user['gender'].value_counts()/sum(user['gender'].value_counts())*100
series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Gênero dos usuários do alfred',
             filename='cufflinks/categorical-bar-chart')
# Out:
# <div>
#
#
#             <div id="ba58a73f-7aa6-4b39-97a9-615cfdd4177d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ba58a73f-7aa6-4b39-97a9-615cfdd4177d")) {
#                     Plotly.newPlot(
#                         'ba58a73f-7aa6-4b39-97a9-615cfdd4177d',
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
series = movie_full['name'].value_counts()/sum(movie_full['name'].value_counts())*100
series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Filmes por gênero',
             filename='cufflinks/categorical-bar-chart')
# Out:
# <div>
#
#
#             <div id="035bcc9a-27bc-4d0a-9234-2e1c85d33c31" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("035bcc9a-27bc-4d0a-9234-2e1c85d33c31")) {
#                     Plotly.newPlot(
#                         '035bcc9a-27bc-4d0a-9234-2e1c85d33c31',
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
series = movie_full.groupby(['name'])['likeCount'].sum()/movie_full['likeCount'].sum()*100

series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Like por gênero do filme',
             filename='cufflinks/categorical-bar-chart')
# Out:
# <div>
#
#
#             <div id="2162a793-3cc4-4cfb-97ef-f77f5b30f089" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2162a793-3cc4-4cfb-97ef-f77f5b30f089")) {
#                     Plotly.newPlot(
#                         '2162a793-3cc4-4cfb-97ef-f77f5b30f089',
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
series = movie_full.groupby(['name'])['wishCount'].sum()/movie_full['wishCount'].sum()*100

series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Wish por gênero do filme',
             filename='cufflinks/categorical-bar-chart')
# Out:
# <div>
#
#
#             <div id="a996ecfb-3378-40ec-9c77-aa8d378b745e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a996ecfb-3378-40ec-9c77-aa8d378b745e")) {
#                     Plotly.newPlot(
#                         'a996ecfb-3378-40ec-9c77-aa8d378b745e',
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
series = movie_full.groupby(['name'])['seenCount'].sum()/movie_full['seenCount'].sum()*100

series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Seen por gênero do filme',
             filename='cufflinks/categorical-bar-chart')
# Out:
# <div>
#
#
#             <div id="7bdd1283-ece5-48e0-8c58-4f0bdad042c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7bdd1283-ece5-48e0-8c58-4f0bdad042c8")) {
#                     Plotly.newPlot(
#                         '7bdd1283-ece5-48e0-8c58-4f0bdad042c8',
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
series = movie_full.groupby(['name'])['notWishCount'].sum()/movie_full['notWishCount'].sum()*100

series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Not Wish por gênero do filme',
             filename='cufflinks/categorical-bar-chart')
# Out:
# <div>
#
#
#             <div id="74d9a7e1-a13f-43ac-a656-c9958a61ab70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("74d9a7e1-a13f-43ac-a656-c9958a61ab70")) {
#                     Plotly.newPlot(
#                         '74d9a7e1-a13f-43ac-a656-c9958a61ab70',
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
series = movie_full.groupby(['name'])['dislikeCount'].sum()/movie_full['dislikeCount'].sum()*100

series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Dislike por gênero do filme',
             filename='cufflinks/categorical-bar-chart')
# Out:
# <div>
#
#
#             <div id="f6e4414b-1e21-4fed-985a-eec871b386f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f6e4414b-1e21-4fed-985a-eec871b386f2")) {
#                     Plotly.newPlot(
#                         'f6e4414b-1e21-4fed-985a-eec871b386f2',
# ...

# %%
movie_full
# Out:
#         id_x  genreId                                           title_x  \
# 0          1        5                     000 - UM AGENTE NADA DISCRETO
# 1          7        5                                MULHER DO CHEFE, A
# 2         13        5                             AGORA VOCÊ NÃO ESCAPA
# 3         18        5                              A VINGANÇA DOS NERDS
# 4         19        5                                   AMOR ALUCINANTE
# 5         21        5                                ARTISTAS E MODELOS
# 6         25        5                                ADMIRADORA SECRETA
# 7         32        5                                ARIZONA NUNCA MAIS
# 8         38        5                                   MEU PRIMO VINNY
# 9         54        5                                         BARCELONA
# 10        55        5                                       BEETHOVEN 2
# 11        61        5                                      O GATO SUMIU
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
series = movie_full.groupby(['name'])[['likeCount','dislikeCount']].sum()/movie_full[['likeCount','dislikeCount']].sum()*100

series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Like e Dislike por gênero do filme',
             filename='cufflinks/grouped-bar-chart')
# df.iplot(kind='bar', filename='cufflinks/grouped-bar-chart')
# Out:
# <div>
#
#
#             <div id="c1699526-0fa5-4a4b-b04e-e0206a09f83d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c1699526-0fa5-4a4b-b04e-e0206a09f83d")) {
#                     Plotly.newPlot(
#                         'c1699526-0fa5-4a4b-b04e-e0206a09f83d',
# ...

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
series = movie_full.groupby(['name'])[['wishCount','notWishCount']].sum()/movie_full[['wishCount','notWishCount']].sum()*100

series.head(3)

series.iplot(kind='bar', yTitle='Porcentagem', title='Wish e not Wish por gênero do filme',
             filename='cufflinks/grouped-bar-chart')
# Out:
# <div>
#
#
#             <div id="a009528f-a4b1-44c9-8aad-bbc29b523065" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a009528f-a4b1-44c9-8aad-bbc29b523065")) {
#                     Plotly.newPlot(
#                         'a009528f-a4b1-44c9-8aad-bbc29b523065',
# ...

# %%
import re
user['geoState']
geoState = []
for k in user['geoState']:
    aux = re.sub(r'State of ','', str(k))
    geoState.append(aux)

user['geoStateLimpo'] = geoState
set(geoState)
# Out:
# {'AC',
#  'AL',
#  'AM',
#  'AP',
#  'Acre',
#  'Alagoas',
#  'Amapá',
#  'Amazonas',
#  'Arizona',
#  'Arkansas',
#  'Auvergne-Rhône-Alpes',
#  'BA',
#  'Bahia',
#  'Bayburt',
#  'CE',
#  'California',
#  'Ceará',
#  'Colorado',
#  'Connecticut',
#  'DF',
#  'Distrito Federal',
#  'ES',
#  'Espírito Santo',
#  'Federal District',
#  'Florida',
#  'GO',
#  'Georgia',
#  'Goiás',
#  'Hauts-de-France',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Lazio',
#  'Louisiana',
#  'MA',
#  'MG',
#  'MS',
#  'MT',
#  'Maine',
#  'Maranhão',
#  'Maryland',
#  'Massachusetts',
#  'Mato Grosso',
#  'Mato Grosso do Sul',
#  'Michigan',
#  'Minas Gerais',
#  'Minnesota',
#  'Missouri',
#  'Nebraska',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'PA',
#  'PB',
#  'PE',
#  'PI',
#  'PR',
#  'Paraná',
#  'Paraíba',
#  'Pará',
#  'Pennsylvania',
# ...

# %%
dict_estados = {
    'AC': 'Acre',
    'AL': 'Alagoas',
    'AP': 'Amapá',
    'AM': 'Amazonas',
    'BA': 'Bahia',
    'CE': 'Ceará',
    'DF': 'Distrito Federal',
    'ES': 'Espírito Santo',
    'GO': 'Goiás',
    'MA': 'Maranhão',
    'MT': 'Mato Grosso',
    'MS': 'Mato Grosso do Sul',
    'MG': 'Minas Gerais',
    'PA': 'Pará',
    'PB': 'Paraíba',
    'PR': 'Paraná',
    'PE': 'Pernambuco',
    'PI': 'Piauí',
    'RJ': 'Rio de Janeiro',
    'RN': 'Rio Grande do Norte',
    'RS': 'Rio Grande do Sul',
    'RO': 'Rondônia',
    'RR': 'Roraima',
    'SC': 'Santa Catarina',
    'SP': 'São Paulo',
    'SE': 'Sergipe',
    'TO': 'Tocantins'
}

# %%
geoState2 = pd.Series(geoState)
user['geoStateLimpoFinal'] = user.geoStateLimpo.map(dict_estados)
user.geoStateLimpoFinal[user.geoStateLimpoFinal.isna() == True] = user.geoStateLimpo[user.geoStateLimpoFinal.isna() == True]

# %%
layout = go.Layout(
    #title='Plot Title',
    xaxis=dict(
        #title='x Axis',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        #title='y Axis',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    font=dict(
#         family='Courier New, monospace',
        size=8,
        color='#7f7f7f'
    )
)

series = user['geoStateLimpoFinal'].value_counts()/sum(user['geoStateLimpoFinal'].value_counts())*100

series_head = series.head(26)

series_head.plot('bar')

# series_head.iplot(kind='bar', yTitle='Porcentagem', title='Usuários do alfred por Estado',
#              filename='cufflinks/categorical-bar-chart')

# %%
data = user.birthday
data2 = data.copy()
data2 = data2.fillna(0)

# %%
for i in range(len(data2)):
    if len(str(data2[i])) <= 4 or int(data2[i][:4]) < 1900 or int(data2[i][:4]) > 2019:
        #print(data2[i])
        data2[i] = 0

data2 = pd.to_datetime(data2)

# %%
age = pd.Timestamp.now().normalize() - pd.to_datetime(data2)
age = age / dt.timedelta(days=365)
user['age'] = age

# %%
age_graf = sns.distplot(age, axlabel = 'Idade');
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
#
#
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
df = movie.merge(movie_mood, how = 'left', left_on = 'id', right_on = 'movieId', suffixes=["_mv", "_mm"])
df = df.merge(mood, how = 'left', left_on = 'moodId', right_on = 'id', suffixes=["_mm", "_md"])
df = df.merge(genre, how = 'left', left_on = 'id_mv', right_on = 'id', suffixes=["_mv", "_gr"])
df = df.merge(user_genre, how = 'left', left_on = 'id_gr', right_on = 'genreId', suffixes=["_gr", "_ug"])
df = df.merge(user, how = 'left', left_on = 'userId', right_on = 'id', suffixes=["_ug", "_u"])

# %%
# df = df.merge(genre, how = 'left', left_on = 'id_mv', right_on = 'id', suffixes=["_mv", "_gr"])
# df = df.merge(user_genre, how = 'left', left_on = 'id_gr', right_on = 'genreId', suffixes=["_gr", "_ug"])
# df = df.merge(user, how = 'left', left_on = 'userId', right_on = 'id', suffixes=["_ug", "_u"])

# %%
filmeEstado = df[['name_gr', 'geoStateLimpoFinal']]

# %%
df.columns
# Out:
# Index(['id_mv', 'genreId_gr', 'title_mm', 'titleOrigin', 'status', 'synopsis',
#        'rating', 'duration', 'year', 'country', 'releaseAt', 'director',
#        'cast', 'thumb_mm', 'image', 'likeCount', 'wishCount', 'seenCount',
#        'video', 'maxRoomsPlaying', 'createdAt_mv', 'updatedAt_mv',
#        'deletedAt_mv', 'search', 'notWishCount', 'dislikeCount', 'id_mm',
#        'movieId', 'moodId', 'createdAt_mm', 'updatedAt_mm', 'id_mv', 'name_mv',
#        'color_mv', 'thumb_md', 'bg', 'title_md', 'subTitle_mv', 'order_mv',
#        'type', 'createdAt_mv', 'updatedAt_mv', 'id_gr', 'name_gr', 'color_gr',
#        'thumb_ug', 'title', 'subTitle_gr', 'order_gr', 'createdAt_gr',
#        'updatedAt_gr', 'deletedAt_gr', 'id_ug', 'genreId_ug', 'userId',
#        'createdAt_ug', 'updatedAt_ug', 'id_u', 'name', 'thumb_u', 'fbid',
#        'email', 'birthday', 'gender', 'zipcode', 'geoCity', 'geoState',
#        'geoAddress', 'geoLat', 'geoLng', 'phone', 'password', 'forgotCode',
# ...

# %%
filmeEstado.shape
# Out:
# (3386258, 2)

# %%
filmeEstado['sum'] = 1

# %%
filmeEstado_dupla = filmeEstado.groupby(['name_gr', 'geoStateLimpoFinal']).sum()
filmeEstado_dupla = filmeEstado_dupla.reset_index()
cat = filmeEstado.groupby('geoStateLimpoFinal').count()
aux = []

# %%
for i in cat.index:
    a = filmeEstado_dupla[filmeEstado_dupla['geoStateLimpoFinal'] == i]['sum']/cat['name_gr'][i]
    a = list(a.values)
    aux.extend(a)

# %%
filmeEstado_dupla['Percent'] = aux

# %%
filmeEstado_dupla = filmeEstado_dupla.sort_values(['geoStateLimpoFinal','Percent'],ascending=False)

# %%
type(filmeEstado['sum'][1])
# Out:
# numpy.int64

# %%
filmeEstado_dupla.drop(columns='Percent')
# Out:
#                 name_gr geoStateLimpoFinal    sum
# 213                Ação      Île-de-France      1
# 345             Comédia      Île-de-France      1
# 68             Animação      Île-de-France      1
# 140            Aventura      Île-de-France      1
# 1753              Ópera                nan   4528
# 622               Drama                nan  21967
# 1523           Suspense                nan  26204
# 1360            Romance                nan  22710
# 344             Comédia                nan  35451
# 407   Comédia Dramática                nan  19216
# 1116           Mistério                nan  24743
# 499               Curta                nan   3942
# 918            Faroeste                nan   8740
# 1049             Horror                nan  16492
# 1588             Terror                nan  20887
# 799             Família                nan  21745
# 471   Comédia Romântica                nan  24585
# 1425            Seriado                nan  23478
# ...

# %%
# filmeEstado_dupla
dict_estados.values()
#filmeEstado_dupla.loc[(filmeEstado_dupla[list(dict_estados)]# == pd.Series(filter_v)).all(axis=1)]
# Out:
# dict_values(['Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão', 'Mato Grosso', 'Mato Grosso do Sul', 'Minas Gerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio de Janeiro', 'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondônia', 'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins'])

# %%
f, ax = plt.subplots(figsize=(9, 6))
filmeEstado_wide = filmeEstado_dupla.pivot("geoStateLimpoFinal", "name_gr", "sum")
b = sns.heatmap(filmeEstado_wide, annot=False, linewidths=.5, ax=ax);
b.tick_params(labelsize=5)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
#sns.barplot(x='geoStateLimpoFinal', y='Percent', hue='name_gr', data=a[a['geoStateLimpoFinal'] == 'São Paulo']);

# %%
movie_full = movie.merge(genre, left_on = 'genreId', right_on = 'id')
# series = movie_full.groupby('name')['likeCount']/sum(movie_full.groupby('name')['likeCount'])*100
movie_full.columns
# Out:
# Index(['id_x', 'genreId', 'title_x', 'titleOrigin', 'status', 'synopsis',
#        'rating', 'duration', 'year', 'country', 'releaseAt', 'director',
#        'cast', 'thumb_x', 'image', 'likeCount', 'wishCount', 'seenCount',
#        'video', 'maxRoomsPlaying', 'createdAt_x', 'updatedAt_x', 'deletedAt_x',
#        'search', 'notWishCount', 'dislikeCount', 'id_y', 'name', 'color',
#        'thumb_y', 'title_y', 'subTitle', 'order', 'createdAt_y', 'updatedAt_y',
#        'deletedAt_y'],
#       dtype='object')

# %%
#movie_full['createdAt_x'] = dt.datetime.strptime(movie_full['createdAt_x'], "%Y-%m-%d %H:%M:%S")
movie_full['createdAt_Month'] = movie_full['createdAt_x'].str[:7]

# %%
movie_full['releaseAt_Month'] = movie_full['releaseAt'].str[:7]

# %%
plt.rcParams['figure.figsize'] = [15, 8]
series = movie_full.groupby(['createdAt_Month','name'])[['seenCount']].sum()/movie_full.groupby(['name'])[['seenCount']].sum()*100
series = series.reset_index(1)

animacao = series[series['name'] == 'Animação']
animacao.plot(title = '', rot = 'vertical')
plt.xlabel('Mês')
# Out:
# Text(0.5, 0, 'Mês')

# %%
for i in range(series['name'].nunique()):
    j = series['name'].unique()[i]
    plt.figure()
    animacao = series[series['name'] == j]
    animacao.plot(rot = 'vertical')
    plt.xlabel('Mês')
    plt.ylabel('Percentual')
    plt.title('Categoria: {0}'.format(j))
    plt.tight_layout()
    plt.savefig('seen_{0}.jpg'.format(i))
    plt.close()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
series
# Out:
#                               name   wishCount
# createdAt_Month
# 2018-03                   Animação   16.999893
# 2018-03                   Aventura   35.900621
# 2018-03                       Ação   27.300062
# 2018-03                  Biografia    2.928023
# 2018-03                    Comédia    9.011329
# 2018-03          Comédia Dramática    9.822499
# 2018-03          Comédia Romântica   11.972212
# 2018-03               Documentário    8.364544
# 2018-03                      Drama   10.866697
# 2018-03                    Erótico  100.000000
# 2018-03               Experimental  100.000000
# 2018-03                    Família    0.014759
# 2018-03                   Fantasia    9.423124
# 2018-03                   Faroeste   96.755162
# 2018-03          Ficção Científica   62.176407
# 2018-03                     Guerra   98.064516
# 2018-03                     Horror    1.283761
# 2018-03                    Musical   23.649289
# 2018-03               Não Definido  100.000000
# ...

# %%
movie.describe()
# Out:
#                  id       genreId      duration          year     likeCount  \
# count  20946.000000  20946.000000  20567.000000  20847.000000  20946.000000
# mean   12098.713215     10.204812     94.175475   1987.274044     74.529027
# std     6856.473500      6.475476     34.331268    121.721207    791.459407
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%     6262.250000      5.000000     88.000000   1986.000000      0.000000
# 50%    11777.500000     11.000000     97.000000   2000.000000      2.000000
# 75%    18135.750000     11.000000    109.000000   2010.000000     11.000000
# max    23642.000000     34.000000    894.000000   2027.000000  41532.000000
#
#           wishCount     seenCount  maxRoomsPlaying  notWishCount  dislikeCount
# count  20946.000000  20946.000000     20946.000000  20946.000000  20946.000000
# mean      63.461043    127.596916         4.298673     13.158407      6.077485
# ...

# %%
user.columns
# Out:
# Index(['id', 'name', 'thumb', 'fbid', 'email', 'birthday', 'gender', 'zipcode',
#        'geoCity', 'geoState', 'geoAddress', 'geoLat', 'geoLng', 'phone',
#        'password', 'forgotCode', 'forgotCodeIssuedAt', 'createdAt',
#        'updatedAt', 'deletedAt', 'privacy', 'durationSeen', 'rankingAll',
#        'geoStateLimpo', 'geoStateLimpoFinal'],
#       dtype='object')

# %%
user["generoSimples"] = user['gender']
cleanup_nums = {"generoSimples":{'masculino':'Masculino', 'feminino':'Feminino', 'male':'Masculino', 'outro':'Outros',
       'female':'Feminino', 'transhomem':'Outros', 'duploespirito':'Outros', 'agenero':'Outros', 'generonaoconformista':'Outros',
       'generoemduvida':'Outros', 'nenhum':'Outros', 'genderqueer':'Outros', 'mulherparahomemftm':'Outros',
       'androgino':'Outros', 'bigenero':'Outros', 'naobinario':'Outros', 'pangenero':'Outros',
       'homemtransexual':'Outros', 'generofluido':'Outros', 'generovariante':'Outros',
       'homemparamulhermtf':'Outros', 'neutrois':'Outros', 'trans':'Outros', 'mulhertransexual':'Outros',
       'transgenero':'Outros', 'transmulher':'Outros', 'transfeminino':'Outros', 'transmasculino':'Outros',
       'intersex':'Outros'},
                "geoStateLimpoFinal":{'Rio Grande do Sul':'Outros', 'São Paulo':'SP', 'Paraná':'Outros', 'Santa Catarina':'Outros',
       'Bahia':'Outros', 'Rio Grande do Norte':'Outros', 'Rio de Janeiro':'RJ', 'Espírito Santo':'Outros',
       'Minas Gerais':'Outros', 'Maranhão':'Outros', 'Pernambuco':'Outros', 'Distrito Federal':'Outros',
       'Tocantins':'Outros', 'Ceará':'Outros', 'Mato Grosso':'Outros', 'Alagoas':'Outros', 'Amapá':'Outros', 'Pará':'Outros',
       'Amazonas':'Outros', 'Goiás':'Outros', 'Mato Grosso do Sul':'Outros', 'Roraima':'Outros', 'Paraíba':'Outros',
       'Sergipe':'Outros', 'Piauí':'Outros', 'Rondônia':'Outros', 'nan':'NA', 'California':'Outros', 'Acre':'Outros',
       'New Jersey':'Outros', 'Kansas':'Outros', 'Texas':'Outros', 'Louisiana':'Outros', 'West Virginia':'Outros',
       'Utah':'Outros', 'Idaho':'Outros', 'Pennsylvania':'Outros', 'Nebraska':'Outros', 'Massachusetts':'Outros',
       'North Carolina':'Outros', 'Arkansas':'Outros', 'New York':'Outros', 'Federal District':'Outros',
       'Virginia':'Outros', 'Colorado':'Outros', 'Maryland':'Outros', 'Vermont':'Outros', 'Arizona':'Outros',
       'Wisconsin':'Outros', 'Ohio':'Outros', 'Auvergne-Rhône-Alpes':'Outros', 'Illinois':'Outros',
       'Île-de-France':'Outros', 'Lazio':'Outros', 'Georgia':'Outros', 'Kentucky':'Outros', 'Indiana':'Outros',
       'Florida':'Outros', 'Washington':'Outros', 'Hauts-de-France':'Outros', 'Missouri':'Outros',
       'North Dakota':'Outros', 'Wyoming':'Outros', 'Queensland':'Outros', 'Iowa':'Outros', 'Minnesota':'Outros',
       'Maine':'Outros', 'Oklahoma':'Outros', 'Michigan':'Outros', 'Hawaii':'Outros', 'Connecticut':'Outros',
       'New Hampshire':'Outros', 'New Mexico':'Outros', 'Bayburt':'Outros', 'South Dakota':'Outros',
       'Rhode Island':'Outros', 'Tennessee':'Outros' }
                }
user.replace(cleanup_nums, inplace=True)

# %%
ax = sns.countplot(x="generoSimples", hue="geoStateLimpoFinal", data=user)

# %%
age_ranges = ["[{0} - {1})".format(age, age + 10) for age in range(10, 100, 10)]
age_ranges
count_unique_age_ranges = len(age_ranges)
count_unique_age_ranges
user['age_range'] = pd.cut(x=user['age'], bins=count_unique_age_ranges, labels=age_ranges)

# %%
ax = sns.countplot(x="generoSimples", hue="age_range", data=user)
# ax.despine(left=True)
plt.legend(loc='upper right')
